# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

# Append project root directory to sys.path
sys.path.append(os.path.abspath(".."))

# Import pipeline functions from src
from src.data import load_raw_dataset
from src.features import build_feature_pipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load sample data and run pipeline
df_raw = load_raw_dataset(data_dir="../data/raw", split="train", nrows=5000)
df_fe = build_feature_pipeline(df_raw)

# Verify generated features
print(f"Original shape: {df_raw.shape}")
print(f"New shape     : {df_fe.shape}")
df_fe[["TransactionID", "uid1", "day_of_week", "hour_of_day", "card1_fq_enc", "TransactionAmt_mean_by_uid1"]].head()
# Out:
# Loading train_transaction.csv...
# Loading train_identity.csv...
# Performing left join on TransactionID...
# Optimizing memory footprint...
# Memory usage decreased to 8.85 MB (46.6% reduction)
# Extracting time features...
# Constructing Pseudo User-IDs (UIDs)...
# Applying Frequency Encoding...
# Computing Group Aggregations & Deviations...
# Feature engineering complete. Total columns: 472
# Original shape: (5000, 434)
# New shape     : (5000, 472)
#    TransactionID                          uid1  day_of_week  hour_of_day  \
# 0        2987000           13926_nan_315.0_nan            1            0
# 1        2987001    2755_404.0_325.0_gmail.com            1            0
# 2        2987002  4663_490.0_330.0_outlook.com            1            0
# 3        2987003   18132_567.0_476.0_yahoo.com            1            0
# 4        2987004    4497_514.0_420.0_gmail.com            1            0
#
#    card1_fq_enc  TransactionAmt_mean_by_uid1
# ...
